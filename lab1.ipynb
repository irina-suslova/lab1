# %%
import pandas as pd

path = "./testsLab1/"

# %%
dataframeListBubbleSort = pd.DataFrame()
dataframeListBubbleSort[["Rand"]] = pd.read_csv(path + "testListRandBubleSort.txt", header = None, sep = '\n')
dataframeListBubbleSort[["Sorted"]] = pd.read_csv(path + "testListSortedBubleSort.txt", header = None, sep = '\n')
dataframeListBubbleSort[["Reversed"]] = pd.read_csv(path + "testListReversedBubleSort.txt", header = None, sep = '\n')
dataframeListBubbleSort[["n"]] = pd.read_csv(path + "indexBubleSort.txt", header = None, sep = '\n')
dataframeListBubbleSort = dataframeListBubbleSort.set_index('n', drop = True)
dataframeListBubbleSort.plot(title = "ListBubleSort")
# Out:
# <AxesSubplot:title={'center':'ListBubleSort'}, xlabel='n'>

# %%
dataframeListShakerSort = pd.DataFrame()
dataframeListShakerSort[["Rand"]] = pd.read_csv(path + "testListRandShakerSort.txt", header = None, sep = '\n')
dataframeListShakerSort[["Sorted"]] = pd.read_csv(path + "testListSortedShakerSort.txt", header = None, sep = '\n')
dataframeListShakerSort[["Reversed"]] = pd.read_csv(path + "testListReversedShakerSort.txt", header = None, sep = '\n')
dataframeListShakerSort[["n"]] = pd.read_csv(path + "indexShakerSort.txt", header = None, sep = '\n')
dataframeListShakerSort = dataframeListShakerSort.set_index('n', drop = True)
dataframeListShakerSort.plot(title = "ListShakerSort")
# Out:
# <AxesSubplot:title={'center':'ListShakerSort'}, xlabel='n'>

# %%
dataframeListMergeSort = pd.DataFrame()
dataframeListMergeSort[["Rand"]] = pd.read_csv(path + "testListRandMergeSort.txt", header = None, sep = '\n')
dataframeListMergeSort[["Sorted"]] = pd.read_csv(path + "testListSortedMergeSort.txt", header = None, sep = '\n')
dataframeListMergeSort[["Reversed"]] = pd.read_csv(path + "testListReversedMergeSort.txt", header = None, sep = '\n')
dataframeListMergeSort[["n"]] = pd.read_csv(path + "indexMergeSort.txt", header = None, sep = '\n')
dataframeListMergeSort = dataframeListMergeSort.set_index('n', drop = True)
dataframeListMergeSort.plot(title = "ListMergeSort")
# Out:
# <AxesSubplot:title={'center':'ListMergeSort'}, xlabel='n'>

# %%
dataframeListHeapSort = pd.DataFrame()
dataframeListHeapSort[["Rand"]] = pd.read_csv(path + "testListRandHeapSort.txt", header = None, sep = '\n')
dataframeListHeapSort[["Sorted"]] = pd.read_csv(path + "testListSortedHeapSort.txt", header = None, sep = '\n')
dataframeListHeapSort[["Reversed"]] = pd.read_csv(path + "testListReversedHeapSort.txt", header = None, sep = '\n')
dataframeListHeapSort[["n"]] = pd.read_csv(path + "indexHeapSort.txt", header = None, sep = '\n')
dataframeListHeapSort = dataframeListHeapSort.set_index('n', drop = True)
dataframeListHeapSort.plot(title = "ListHeapSort")
# Out:
# <AxesSubplot:title={'center':'ListHeapSort'}, xlabel='n'>

# %%
dataframeListQuickSort = pd.DataFrame()
dataframeListQuickSort[["Rand"]] = pd.read_csv(path + "testListRandQuickSort.txt", header = None, sep = '\n')
dataframeListQuickSort[["Sorted"]] = pd.read_csv(path + "testListSortedQuickSort.txt", header = None, sep = '\n')
dataframeListQuickSort[["Reversed"]] = pd.read_csv(path + "testListReversedQuickSort.txt", header = None, sep = '\n')
dataframeListQuickSort[["n"]] = pd.read_csv(path + "indexQuickSort.txt", header = None, sep = '\n')
dataframeListQuickSort = dataframeListQuickSort.set_index('n', drop = True)
dataframeListQuickSort.plot(title = "ListQuickSort")
# Out:
# <AxesSubplot:title={'center':'ListQuickSort'}, xlabel='n'>

# %%
dataframeArrayBubbleSort = pd.DataFrame()
dataframeArrayBubbleSort[["Rand"]] = pd.read_csv(path + "testArrayRandBubleSort.txt", header = None, sep = '\n')
dataframeArrayBubbleSort[["Sorted"]] = pd.read_csv(path + "testArraySortedBubleSort.txt", header = None, sep = '\n')
dataframeArrayBubbleSort[["Reversed"]] = pd.read_csv(path + "testArrayReversedBubleSort.txt", header = None, sep = '\n')
dataframeArrayBubbleSort[["n"]] = pd.read_csv(path + "indexBubleSort.txt", header = None, sep = '\n')
dataframeArrayBubbleSort = dataframeArrayBubbleSort.set_index('n', drop = True)
dataframeArrayBubbleSort.plot(title = "ArrayBubleSort")
# Out:
# <AxesSubplot:title={'center':'ArrayBubleSort'}, xlabel='n'>

# %%
dataframeArrayShakerSort = pd.DataFrame()
dataframeArrayShakerSort[["Rand"]] = pd.read_csv(path + "testArrayRandShakerSort.txt", header = None, sep = '\n')
dataframeArrayShakerSort[["Sorted"]] = pd.read_csv(path + "testArraySortedShakerSort.txt", header = None, sep = '\n')
dataframeArrayShakerSort[["Reversed"]] = pd.read_csv(path + "testArrayReversedShakerSort.txt", header = None, sep = '\n')
dataframeArrayShakerSort[["n"]] = pd.read_csv(path + "indexShakerSort.txt", header = None, sep = '\n')
dataframeArrayShakerSort = dataframeArrayShakerSort.set_index('n', drop = True)
dataframeArrayShakerSort.plot(title = "ArrayShakerSort")
# Out:
# <AxesSubplot:title={'center':'ArrayShakerSort'}, xlabel='n'>

# %%
dataframeArrayMergeSort = pd.DataFrame()
dataframeArrayMergeSort[["Rand"]] = pd.read_csv(path + "testArrayRandMergeSort.txt", header = None, sep = '\n')
dataframeArrayMergeSort[["Sorted"]] = pd.read_csv(path + "testArraySortedMergeSort.txt", header = None, sep = '\n')
dataframeArrayMergeSort[["Reversed"]] = pd.read_csv(path + "testArrayReversedMergeSort.txt", header = None, sep = '\n')
dataframeArrayMergeSort[["n"]] = pd.read_csv(path + "indexMergeSort.txt", header = None, sep = '\n')
dataframeArrayMergeSort = dataframeArrayMergeSort.set_index('n', drop = True)
dataframeArrayMergeSort.plot(title = "ArrayMergeSort")
# Out:
# <AxesSubplot:title={'center':'ArrayMergeSort'}, xlabel='n'>

# %%
dataframeArrayHeapSort = pd.DataFrame()
dataframeArrayHeapSort[["Rand"]] = pd.read_csv(path + "testArrayRandHeapSort.txt", header = None, sep = '\n')
dataframeArrayHeapSort[["Sorted"]] = pd.read_csv(path + "testArraySortedHeapSort.txt", header = None, sep = '\n')
dataframeArrayHeapSort[["Reversed"]] = pd.read_csv(path + "testArrayReversedHeapSort.txt", header = None, sep = '\n')
dataframeArrayHeapSort[["n"]] = pd.read_csv(path + "indexHeapSort.txt", header = None, sep = '\n')
dataframeArrayHeapSort = dataframeArrayHeapSort.set_index('n', drop = True)
dataframeArrayHeapSort.plot(title = "ArrayHeapSort")
# Out:
# <AxesSubplot:title={'center':'ArrayHeapSort'}, xlabel='n'>

# %%
dataframeArrayQuickSort = pd.DataFrame()
dataframeArrayQuickSort[["Rand"]] = pd.read_csv(path + "testArrayRandQuickSort.txt", header = None, sep = '\n')
dataframeArrayQuickSort[["Sorted"]] = pd.read_csv(path + "testArraySortedQuickSort.txt", header = None, sep = '\n')
dataframeArrayQuickSort[["Reversed"]] = pd.read_csv(path + "testArrayReversedQuickSort.txt", header = None, sep = '\n')
dataframeArrayQuickSort[["n"]] = pd.read_csv(path + "indexQuickSort.txt", header = None, sep = '\n')
dataframeArrayQuickSort = dataframeArrayQuickSort.set_index('n', drop = True)
dataframeArrayQuickSort.plot(title = "ArrayQuickSort")
# Out:
# <AxesSubplot:title={'center':'ArrayQuickSort'}, xlabel='n'>
